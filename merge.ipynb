# %%
import pandas as pd

linkGoogle="https://docs.google.com/spreadsheets/d/e/2PACX-1vTGGxCfvJdmpImkqtl9m2AhvnBdV8T6xl03DVoMAYTrvZB_DImLJL3oJIfhELELXMJuwA2-UwNdmELH/pub?gid=421607132&single=true&output=csv"
datadis=pd.read_csv(linkGoogle)

# %%
datadis
# Out:
#       Ubigeo Departamento    Provincia                Distrito  Poblacion  \
# 0      10101     Amazonas  Chachapoyas             CHACHAPOYAS      29171
# 1      10102     Amazonas  Chachapoyas                ASUNCION        288
# 2      10103     Amazonas  Chachapoyas                  BALSAS       1644
# 3      10104     Amazonas  Chachapoyas                   CHETO        591
# 4      10105     Amazonas  Chachapoyas               CHILIQUIN        687
# ...      ...          ...          ...                     ...        ...
# 1869  250302      Ucayali   Padre Abad                 IRAZOLA      10830
# 1870  250303      Ucayali   Padre Abad                CURIMANA       8956
# 1871  250304      Ucayali   Padre Abad                 NESHUYA       8445
# 1872  250305      Ucayali   Padre Abad  ALEXANDER VON HUMBOLDT       6678
# 1873  250401      Ucayali        Purus                   PURUS       4657
#
#       Superficie  Den_pob  RENIEC  POB-PEN  ES_PRIV  ...  \
# ...

# %%
import geopandas as gpd

linkGit="https://github.com/chorrillos/preprocesamiento/raw/main/distritos/DISTRITOS1874.shp"
datadismap=gpd.read_file(linkGit)
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: '/vsimem/4c0020b6b72843db9f85b7403fefdbb1' not recognized as a supported file format.
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/ipykernel_9980/1232407174.py in <module>
#       2
#       3 linkGit="https://github.com/chorrillos/preprocesamiento/raw/main/distritos/DISTRITOS1874.shp"
# ----> 4 datadismap=gpd.read_file(linkGit)
#
# ~/anaconda3/envs/SpatialPython/lib/python3.8/site-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#     199
#     200     with fiona_env():
# ...
